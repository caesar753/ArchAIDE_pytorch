# %% [markdown]
# <br><b>resnet50, SGD, lr = 0.005 -> down:</b>
# <br>Train: Epoch [10/10], lter [1385/1387] Loss: 2.2461, Accuracy:24.5422 %
# <br>val: Epoch: 10, batch 5, learning rate 0.005: 19.294118 %
# <br>
# <br><b>resnet50, epochs:30,batch:5, learning rate: 0.005, Intermediate features: 1024, Dropout:0.1, optimizer: SGD (initial_lr: 0.005, momentum: 0.9, gamma:0.9):</b>
# <br>Training: Total batch: [1387], Loss:2.4551050156763154, Accuracy: 36.49603271484375%,
# <br>Validation: batch size:[596], Loss: 2.746513008571311, Accuracy: 31.543624877929688%
# <br>
# <br><b>resnet50, epochs:100,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.2,  optimizer: SGD (initial_lr: 0.001, lr: 0.00059049, momentum: 0.9): </b>
#  <br>Training: Total batch: [1387], Loss:0.9954818141772247, Accuracy: top1: 72.19898986816406%, top5: 90.07930755615234%
# <br>Validation: batch size:[596], Loss: 2.312121729322728, Accuracy: 47.852352142333984%, top5: 76.71141052246094%
# <br>
# <br><b>resnet101, SGD, lr = 0.001:</b>
# <br>Train: Epoch [10/10], lter [1385/1387] Loss: 2.5122, Accuracy:35.4867 %
# <br>val: Epoch: 10, batch 5, learning rate 0.001: 30.521008 %
# <br>
# <br><b>resnet101, epochs:30,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.1, optimizer: SGD (initial_lr: 0.001, momentum: 0.9):</b>
# <br>Training: Total batch: [1387], Loss:1.9070797108795974, Accuracy: 49.5313606262207%,
# <br>Validation: batch size:[596], Loss: 2.312925016770027, Accuracy: 39.832218170166016%
# <br>
# <br><b>inception_v3, epochs:10, batch:5, RMSProp, lr = 0.005</b>
# <br>Train: Epoch [10/10], lter [1385/1387] Loss: 4.0242, Accuracy:5.7967 %
# <br>val: Epoch: 10, batch 5, learning rate 0.005: 5.478992 %
# <br>
# <br>
# <br><b>inception_v3, rmsprop, epochs:30,batch:5, learning rate: 0.001,</b>
#  <br>Training: Total batch: [1387], Loss:2.7605169175680198, Accuracy: 29.76207733154297%,
#  <br>Validation: batch size:[596], Loss: 3.074964640624571, Accuracy: 26.140939712524414%
#  <br>
#  <br><b>inception_v3, rmsprop, epochs:10,batch:5, learning rate: 0.001,</b>
#  <br>Training: Total batch: [1387], Loss:3.6602959521141685, Accuracy: 8.695025444030762%
#  <br>Validation: batch size:[596], Loss: 3.6893323687899033, Accuracy: 8.355704307556152
#  <br>
#  <br>
# <br><b>resnet101, epochs:30,batch:5, learning rate: 0.005, Intermediate features: 1024, Dropout:0.1, optimizer: SGD (initial_lr: 0.005, lr: 0.0045000000000000005, momentum: 0.9): </b>
# <br>Training: Total batch: [1387], Loss:3.9061428364352864, Accuracy: top1: 5.897620677947998%, top5: 21.715932846069336%
# <br>Validation: batch size:[596], Loss: 3.9124323605691025, Accuracy: 5.469799041748047%, top5: 20.738256454467773%
# <br>
# <br>

# %% [markdown]
# # Inception

# %% [markdown]
# <b>inception_v3, epochs:100,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.1, optimizer: SGD (initial_lr: 0.001, lr: 0.00059049, momentum: 0.9):</b>
# <br>Training: Total batch: [1387], Loss:1.176287244734097, Accuracy: top1: 68.8248062133789%, top5: 87.42610168457031%
# <br>Validation: batch size:[596], Loss: 2.4894470661978594, Accuracy: 40.87248611450195%, top5: 71.24160766601562%
# <br>
# <br><b>inception_v3, epochs:100,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.3, optimizer: SGD (initial_lr: 0.001, lr: 0.00059049, momentum: 0.9):</b>
# <br>Training: Total batch: [1387], Loss:1.1591198390125477, Accuracy: top1: 68.72386169433594%, top5: 87.88752746582031%
# <br>Validation: batch size:[596], Loss: 2.5202105334591147, Accuracy: 40.53691482543945%, top5: 72.04698181152344%
# <br>
# <br><b>inception_v3, epochs:100,batch:5, learning rate: 0.005, Intermediate features: 1024, Dropout:0.3, optimizer: SGD (initial_lr: 0.005, lr: 0.002952450000000001, momentum: 0.9):</b>
# <br> Training: Total batch: [1387], Loss:1.6632961731782772, Accuracy: top1: 55.71737289428711%, top5: 80.49026489257812%
# <br>Validation: batch size:[596], Loss: 3.061994845560133, Accuracy: 35.6375846862793%, top5: 64.63087463378906%
# <br>
# <br><font size = "4"> <b>Learning rate variation</b> </font>
# <br><b>inception_v3, epochs:30,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.1, optimizer: SGD (initial_lr: 0.001, momentum: 0.9, gamma: 0.9):</b>
# <br>Training: Total batch: [1387], Loss:1.7883498579500043, Accuracy: 51.5068473815918%,
# <br>Validation: batch size:[596], Loss: 2.4465255082253643, Accuracy: 38.087249755859375%
# <br>
# <br><b>inception_v3,      epochs:30,batch:5, learning rate: 0.005, Intermediate features: 1024, Dropout:0.1, optimizer: SGD (initial_lr: 0.005, momentum: 0.9, gamma:0.9):</b>
# <br>Training: Total batch: [1387], Loss:1.9012927699568207, Accuracy: 49.54578399658203%,
# <br> Validation: batch size:[596], Loss: 2.7922669596620056, Accuracy: 35.7047004699707%
# <br>
# <br><b>inception_v3, epochs:30,batch:5, learning rate: 0.01, Intermediate features: 1024, Dropout:0.1, optimizer: SGD (initial_lr: 0.01, lr: 0.009000000000000001, momentum: 0.9): </b>
# <br>Training: Total batch: [1387], Loss:2.9788888523968846, Accuracy: 25.320837020874023%,                   <br>Validation: batch size:[596], Loss: 3.0894043481589963, Accuracy: 22.85234832763672%
# <br>
# <br><font size = "4"> <b>Dropout variation</b> </font>
# <br><b> inception_v3, epochs:10,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.1, optimizer: SGD (initial_lr: 0.001, momentum: 0.9):</b>
# <br>Training: Total batch: [1387], Loss: 2.8309, Accuracy:38.9618 %
# <br> Validation: batch size:[596], learning rate 0.001, iter: [595/596]: 32.605042 %
# <br><b>inception_v3, epochs:10,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.2, optimizer: SGD (initial_lr: 0.001, momentum: 0.9):</b>
# <br>Training: Total batch: [1387], Loss:2.388960719151555, Accuracy: top1: 38.68781661987305%, top5: 68.91132354736328%
# <br>Validation: batch size:[596], Loss: 2.673651351724695, Accuracy: 31.711410522460938%, top5: 62.91946792602539%
# <br>
# <br><b> inception_v3, epochs:10,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.3, optimizer: SGD (initial_lr: 0.001, momentum: 0.9):</b>
# <br> Training: Total batch: [1387], Loss:2.4152175465675247, Accuracy: top1: 37.82263946533203%, top5: 67.584716796875%
# <br> Validation: batch size:[596], Loss: 2.677879222487443, Accuracy: 31.17449951171875%, top5: 63.18791961669922%
# <br>
# <br><b> inception_v3, epochs:10,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.4, optimizer: SGD (initial_lr: 0.001, momentum: 0.9):</b>
# <br>Training: Total batch: [1387], Loss:2.424404711025433, Accuracy: top1: 38.34174728393555%, top5: 68.03172302246094%
# <br>Validation: batch size:[596], Loss: 2.6631109764511955, Accuracy: 31.07382583618164%, top5: 63.89262008666992%
# <br><b> inception_v3, epochs:10,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.5, optimizer: SGD (initial_lr: 0.001, momentum: 0.9):</b>
# <br>Training: Total batch: [1387], Loss:2.425514915819725, Accuracy: top1: 37.33237075805664%, top5: 67.95962524414062%
# <br>Validation: batch size:[596], Loss: 2.6617301389474997, Accuracy: 32.013423919677734%, top5: 62.684566497802734%

# %% [markdown]
# # ResNet50

# %% [markdown]
# <font size = "4"> <b>Dropout variation </b></font>
#
# <br><b>resnet50, epochs:10,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.1, optimizer: SGD (initial_lr: 0.001, lr: 0.001, momentum: 0.9): </b>
# <br>Training: Total batch: [1387], Loss:2.228356772519396, Accuracy: 41.384281158447266%, top5: 72.32876586914062%
# <br>Validation: batch size:[596], Loss: 2.4279485050863867, Accuracy: 35.939598083496094%, top5: 70.2684555053711%
# <br>
# <br><b>resnet50, epochs:10,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.2, optimizer: SGD (initial_lr: 0.001, momentum: 0.9): </b>
# <br> Training: Total batch: [1387], Loss:2.166340748375925, Accuracy: top1: 42.60995101928711%, top5: 73.06416320800781%
# <br> Validation: batch size:[596], Loss: 2.3548496446053453, Accuracy: 37.41611099243164%, top5: 71.0067138671875%
# <br>
# <br><b>resnet50, epochs:10,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.3, optimizer: SGD (initial_lr: 0.001, momentum: 0.9)</b>
# <br>Training: Total batch: [1387], Loss:2.203621733452918, Accuracy: top1: 41.917808532714844%, top5: 71.69430541992188%
# <br>Validation: batch size:[596], Loss: 2.413734736658583, Accuracy: 36.20805358886719%, top5: 70.97315979003906%
# <br>
# <br><b>resnet50, epochs:10,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.4, optimizer: SGD (initial_lr: 0.001, momentum: 0.9):</b>
# <br>Training: Total batch: [1387], Loss:2.242672821817075, Accuracy: top1: 41.73035430908203%, top5: 71.65104675292969%
# <br>Validation: batch size:[596], Loss: 2.455036047721069, Accuracy: 35.671142578125%, top5: 69.12751770019531%
# <br>
# <br><b>resnet50, epochs:10,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.5, optimizer: SGD (initial_lr: 0.001, momentum: 0.9):</b>
# <br>Training: Total batch: [1387], Loss:2.2390047143325584, Accuracy: top1: 42.06200408935547%, top5: 71.52127075195312%
# <br>Validation: batch size:[596], Loss: 2.4073682467409427, Accuracy: 37.348995208740234%, top5: 69.93289184570312%
# <br>
# <br><font size = "3"> <b>Dropout variation: only one layer </b></font>
# <br>
# <br><b>resnet50, epochs:10,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.1, optimizer: SGD (initial_lr: 0.001, lr: 0.001, momentum: 0.9):</b>
# <br>Training: Total batch: [1387], Loss:2.1919249352484016, Accuracy: top1: 42.033164978027344%, top5: 72.84786987304688%
# <br>Validation: batch size:[596], Loss: 2.394337948936744, Accuracy: 36.57718276977539%, top5: 68.9597396850586%
# <br>
# <br><font size = "4"> <b>Batch variation </b></font>
# <br>
# <br><b>resnet50, epochs:10,batch:10, learning rate: 0.001, Intermediate features: 1024, Dropout:0.1, optimizer: SGD (initial_lr: 0.001, lr: 0.001, momentum: 0.9)</b>
# <br>Training: Total batch: [693], Loss:2.293156072142834, Accuracy: top1: 40.50468444824219%, top5: 70.88681030273438%
# <br>Validation: batch size:[298], Loss: 2.4690686268294417, Accuracy: 35.3691291809082%, top5: 68.62416076660156%
# <br>
# <br><b>resnet50, epochs:10,batch:10, learning rate: 0.001, Intermediate features: 1024, Dropout:0.3, optimizer: SGD (initial_lr: 0.001, lr: 0.001, momentum: 0.9):</b>
# <br> Training: Total batch: [693], Loss:2.2602066632733555, Accuracy: top1: 41.326602935791016%, top5: 71.52127075195312%
# <br> Validation: batch size:[298], Loss: 2.469002680890512, Accuracy: 36.3087272644043%, top5: 68.52349090576172%
# <br>
# <br><b>resnet50, epochs:10,batch:10, learning rate: 0.005, Intermediate features: 1024, Dropout:0.3, optimizer: SGD (initial_lr: 0.005, lr: 0.005, momentum: 0.9): </b>
# <br> Training: Total batch: [693], Loss:2.2036368439501794, Accuracy: top1: 41.643836975097656%, top5: 71.44917297363281%
# <br> Validation: batch size:[298], Loss: 2.701216301061963, Accuracy: 34.328861236572266%, top5: 67.6174545288086%
# <br>
# <br><b>resnet50, epochs:30,batch:10, learning rate: 0.005, Intermediate features: 1024, Dropout:0.3, optimizer: SGD (Parameter Group 0, initial_lr: 0.005, lr: 0.0045000000000000005, momentum: 0.9): </b>
# <br>Training: Total batch: [693], Loss:1.6762566423794307, Accuracy: top1: 54.79452133178711%, top5: 81.2689208984375%
# <br>Validation: batch size:[298], Loss: 2.422486293835928, Accuracy: 41.84564208984375%, top5: 72.38255310058594%
# <br>
# <br><font size = "4"> <b>Double intermediate features </b></font>
# <br>
# <br><b>resnet50, epochs:10,batch:5, learning rate: 0.001, Intermediate features: first layer:1024, second layer:512,    Dropout:0.1, optimizer: SGD (initial_lr: 0.001, lr: 0.001, momentum: 0.9):</b>
# <br>Training: Total batch: [1387], Loss:2.2400372652115372, Accuracy: top1: 41.39870071411133%, top5: 72.08363342285156%
# <br>Validation: batch size:[596], Loss: 2.538346299789096, Accuracy: 34.228187561035156%, top5: 68.48992919921875%
# <br>
# <br><b>resnet50, epochs:10,batch:5, learning rate: 0.001, Intermediate features: 1024, Dropout:0.1, optimizer: SGD (initial_lr: 0.001, lr: 0.001, momentum: 0.9):</b>
# <br>Training: Total batch: [1387], Loss:2.1919249352484016, Accuracy: top1: 42.033164978027344%, top5: 72.84786987304688%
# <br>Validation: batch size:[596], Loss: 2.394337948936744, Accuracy: 36.57718276977539%, top5: 68.9597396850586%
# <br>
